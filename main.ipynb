# %%
"""Módulo principal para ejecutar la aplicación: Envío masivo de correos"""

# from contacts import contacts
from outlook import outlook
from Classes.email_class import SendEmails
from helper.notion_helper import ContactColumns, Target

PLANTA = Target.PLANTA.value
MINA = Target.MINA.value
TUBERIA = Target.TUBERIA.value
COMPRAS =Target.COMPRAS.value

CONTACT_FILTERED = [
    (
        ContactColumns.AREA.value,
        [COMPRAS, PLANTA, MINA, TUBERIA]
    )
]

if __name__ == "__main__":
    emails = SendEmails()
    #emails.set_contacts(contacts)
    emails.get_contacts(test=False, filter_columns=CONTACT_FILTERED)
    emails.set_subject("Liners con sensores presentados en la CIM (Canadian Institute of Mining)")
    emails.send(outlook)
# Out:
# Cargando contactos desde Notion...
# None
# {'start_cursor': 'a5a368b4-b617-467b-9655-7a529358388a'}
# {'start_cursor': 'd3a017ed-3d66-408a-ae16-5e1e829ec6c6'}
# {'start_cursor': '1f18ad81-fd3b-408a-8412-545922b4d34c'}
# {'start_cursor': '4382b556-18ea-49b9-beb3-4a53bf8862b7'}
# ==================================================
# Fueron encontrados 421 contactos en Notion
# ==================================================
# ==================================================
# 421 Contactos transformados a DataFrame con propiedades de interés
# ==================================================
# ==================================================
# Resultados del primer filtrado: 259 contactos
# ==================================================
# Filtro: Area ---> Compras
# Filtro: Area ---> Planta
# Filtro: Area ---> Mina
# Filtro: Area ---> Tuberia
# ==================================================
# Resultado de aplicar filtros: 228 contactos pasaron los filtros
# ============================================================
# Estas en modo PRODUCCIÓN
# Enviarás el correo a: 228 contacto(s)
# Estas seguro de continuar?:
# S - Si
# N - No
#  s
# {'Nombre': 'Carlos Camacho', 'Correo': 'carlos.camacho@minsur.com', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 1 / 228 enviado
# ============================================================
# {'Nombre': 'Arístides Valdivia', 'Correo': 'avaldiviah@chinalco.com.pe', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 2 / 228 enviado
# ============================================================
# {'Nombre': 'Jose Vasquez', 'Correo': 'jvasquez@chinalco.com.pe', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 3 / 228 enviado
# ============================================================
# {'Nombre': 'David Poma', 'Correo': 'dpomag@cosapi.com.pe', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 4 / 228 enviado
# ============================================================
# {'Nombre': 'José Chavez', 'Correo': 'Jose.Chavez@mmg.com', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 5 / 228 enviado
# ============================================================
# {'Nombre': 'Hernan Vega', 'Correo': 'Hernan.Vega@mmg.com', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 6 / 228 enviado
# ============================================================
# {'Nombre': 'Paul Ramirez', 'Correo': 'pramirez@poderosa.com.pe', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 7 / 228 enviado
# ============================================================
# {'Nombre': 'Carlos David, Flores Ticona', 'Correo': 'cflorest@fmi.com', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 8 / 228 enviado
# ============================================================
# {'Nombre': 'Julvers Álvarez', 'Correo': 'jalvarez5@fmi.com', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 9 / 228 enviado
# ============================================================
# {'Nombre': 'David Oswald Garcia Romero', 'Correo': 'dgarciar@fmi.com', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 10 / 228 enviado
# ============================================================
# {'Nombre': 'David Roca', 'Correo': 'droca@chinalco.com.pe', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 11 / 228 enviado
# ============================================================
# {'Nombre': 'Edgar Peña', 'Correo': 'epena@southernperu.com.pe ', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 12 / 228 enviado
# ============================================================
# {'Nombre': 'Richard Pareja', 'Correo': 'richard.pareja@angloamerican.com', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 13 / 228 enviado
# ============================================================
# {'Nombre': 'Ramiro Alberto Oviedo Lopez', 'Correo': 'ROviedo@SouthernPeru.com.pe', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 14 / 228 enviado
# ============================================================
# {'Nombre': 'Luis Jimenez', 'Correo': 'ljimenez@chinalco.com.pe', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 15 / 228 enviado
# ============================================================
# {'Nombre': 'Aldo García', 'Correo': 'aldo.garcia@hudbayminerals.com', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 16 / 228 enviado
# ============================================================
# {'Nombre': 'Marcos Pozo Ramirez', 'Correo': 'mpozo@chinalco.com.pe', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 17 / 228 enviado
# ============================================================
# {'Nombre': 'Jorge Acuña', 'Correo': 'jacuna@chinalco.com.pe', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 18 / 228 enviado
# ============================================================
# {'Nombre': 'Edmundo Valverde', 'Correo': 'evalverd@fmi.com', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 19 / 228 enviado
# ============================================================
# {'Nombre': 'Hambert Tejada Torres', 'Correo': 'Hambert.tejada@mmg.com', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 20 / 228 enviado
# ============================================================
# {'Nombre': 'Angel Del Castillo', 'Correo': 'ANGEL.DELCASTILLO@miskimayo.com', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 21 / 228 enviado
# ============================================================
# {'Nombre': 'Edwin Tapia', 'Correo': 'etapia@chinalco.com.pe', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 22 / 228 enviado
# ============================================================
# {'Nombre': 'Julio César Bautista Salas', 'Correo': 'jbautista@antamina.com', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 23 / 228 enviado
# ============================================================
# {'Nombre': 'Omar Castillo', 'Correo': 'ocastillo@chinalco.com.pe', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 24 / 228 enviado
# ============================================================
# {'Nombre': 'Freddy Nina', 'Correo': 'fnina@chinalco.com.pe', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 25 / 228 enviado
# ============================================================
# {'Nombre': 'José Terrones', 'Correo': 'jterrones@chinalco.com.pe', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 26 / 228 enviado
# ============================================================
# {'Nombre': 'Hugo Román', 'Correo': 'hromanme@fmi.com', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 27 / 228 enviado
# ============================================================
# {'Nombre': 'Ramiro Vargas', 'Correo': 'rvargasv6@hotmail.com', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 28 / 228 enviado
# ============================================================
# {'Nombre': 'Derly Vizcarra', 'Correo': 'derly.vizcarra@mmg.com', 'Area': 'Mina', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 29 / 228 enviado
# ============================================================
# {'Nombre': 'Luz Arazola', 'Correo': 'LArazolaC@SouthernPeru.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 30 / 228 enviado
# ============================================================
# {'Nombre': 'Franklin Piñas', 'Correo': 'fperez@antamina.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 31 / 228 enviado
# ============================================================
# {'Nombre': 'Fernando Perez', 'Correo': 'fperez@antamina.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 32 / 228 enviado
# ============================================================
# {'Nombre': 'Jesus Salazar', 'Correo': 'jesussalazar@teslatechnology.com.ve', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Venezuela'}
# Correo 33 / 228 enviado
# ============================================================
# {'Nombre': 'Anita Monterola', 'Correo': 'anita.monterola@hudbayminerals.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 34 / 228 enviado
# ============================================================
# {'Nombre': 'Hector Janampa', 'Correo': 'hector.janampa@mmg.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 35 / 228 enviado
# ============================================================
# {'Nombre': 'Jose Luperdi', 'Correo': 'jose.luperdi@miskimayo.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 36 / 228 enviado
# ============================================================
# {'Nombre': 'Tomas Maldonado', 'Correo': 'Tomas.Maldonado@minsur.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 37 / 228 enviado
# ============================================================
# {'Nombre': 'Jose Barrera', 'Correo': 'Jose.Barrera@minsur.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 38 / 228 enviado
# ============================================================
# {'Nombre': 'Miguel Rojas', 'Correo': 'Miguel.Rojas@MMG.COM', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': ''}
# Correo 39 / 228 enviado
# ============================================================
# {'Nombre': 'Ed Arzapalo', 'Correo': 'ed.arzapalo@mmg.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 40 / 228 enviado
# ============================================================
# {'Nombre': 'Christian Dávila', 'Correo': 'christian.davila@minsur.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 41 / 228 enviado
# ============================================================
# {'Nombre': 'Julio Avalos', 'Correo': 'julio.avalos@minsur.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 42 / 228 enviado
# ============================================================
# {'Nombre': 'Ana Carbajal', 'Correo': 'ana.carbajal@hudbayminerals.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 43 / 228 enviado
# ============================================================
# {'Nombre': 'Jaime Gonzalez', 'Correo': 'jgonzales@antamina.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 44 / 228 enviado
# ============================================================
# {'Nombre': 'Albert Diaz Torres', 'Correo': 'adiazt@SouthernPeru.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 45 / 228 enviado
# ============================================================
# {'Nombre': 'Freimy Blanco Fernandez', 'Correo': 'fblanco@chinalco.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 46 / 228 enviado
# ============================================================
# {'Nombre': 'José Munayco', 'Correo': 'jmunayco@chinalco.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 47 / 228 enviado
# ============================================================
# {'Nombre': 'Hans Chavez', 'Correo': 'hans.chavez@spm.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 48 / 228 enviado
# ============================================================
# {'Nombre': 'Armando Ccama Surco', 'Correo': 'armando.ccama@hudbayminerals.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 49 / 228 enviado
# ============================================================
# {'Nombre': 'Billy Estrada Tejada', 'Correo': 'billy.estrada@hudbayminerals.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 50 / 228 enviado
# ============================================================
# {'Nombre': 'MARX SALAZAR REYNAGA', 'Correo': 'marx.salazar@hudbayminerals.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 51 / 228 enviado
# ============================================================
# {'Nombre': 'Alain Andres Yance Paucar', 'Correo': 'alain.yance@hudbayminerals.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 52 / 228 enviado
# ============================================================
# {'Nombre': 'Victor Manchego', 'Correo': 'victor.manchego@hudbayminerals.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 53 / 228 enviado
# ============================================================
# {'Nombre': 'Ciro Diaz Gonzales', 'Correo': 'ciro.diaz@hudbayminerals.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 54 / 228 enviado
# ============================================================
# {'Nombre': 'Jafet Elvis Mollapaza Quispe', 'Correo': 'jafet.mollapaza@hudbayminerals.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 55 / 228 enviado
# ============================================================
# {'Nombre': 'Wilfredo Motta Castillo', 'Correo': 'wilfredo.motta@hudbayminerals.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 56 / 228 enviado
# ============================================================
# {'Nombre': 'Victor Salazar ', 'Correo': 'victor.salazar@hudbayminerals.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 57 / 228 enviado
# ============================================================
# {'Nombre': 'Planificación de Mantenimiento', 'Correo': 'hudbay.peru.planning.maintenance@hudbayminerals.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 58 / 228 enviado
# ============================================================
# {'Nombre': 'Yoselyn Noriega', 'Correo': 'yoselyn.noriega@zafranal.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 59 / 228 enviado
# ============================================================
# {'Nombre': 'Giancarlo Miguel Granda Melendez', 'Correo': 'giancarlo.granda@minsur.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 60 / 228 enviado
# ============================================================
# {'Nombre': 'Alberto Collantes Saint-Pere', 'Correo': 'alberto.collantes@minsur.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 61 / 228 enviado
# ============================================================
# {'Nombre': 'Ana Yucra Torres', 'Correo': 'AYucraT@SouthernPeru.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': ''}
# Correo 62 / 228 enviado
# ============================================================
# {'Nombre': 'Peter Alvarado', 'Correo': 'peter.alvarado@spm.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': ''}
# Correo 63 / 228 enviado
# ============================================================
# {'Nombre': 'Emmanuel Quispe', 'Correo': 'equispev@mibsac.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 64 / 228 enviado
# ============================================================
# {'Nombre': 'Emerson Ulloa', 'Correo': 'Eulloa@Southernperu.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 65 / 228 enviado
# ============================================================
# {'Nombre': 'Jorge Gomez', 'Correo': 'jorge.gomez@sierrametals.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 66 / 228 enviado
# ============================================================
# {'Nombre': 'Diógenes Roque', 'Correo': 'DRoque@SouthernPeru.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 67 / 228 enviado
# ============================================================
# {'Nombre': 'Marco Antonio Cespedes', 'Correo': 'mcespedes@alpayana.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 68 / 228 enviado
# ============================================================
# {'Nombre': 'Arturo Torres', 'Correo': 'atorres@acerosarequipa.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': ''}
# Correo 69 / 228 enviado
# ============================================================
# {'Nombre': 'Susana García', 'Correo': 'sgarcia@chinalco.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 70 / 228 enviado
# ============================================================
# {'Nombre': 'Oscar Romero', 'Correo': 'ORomeroS@SouthernPeru.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 71 / 228 enviado
# ============================================================
# {'Nombre': 'Armida Valverde', 'Correo': 'armida.valverde@spm.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 72 / 228 enviado
# ============================================================
# {'Nombre': 'Vlademir Bastidas', 'Correo': 'vlademir.bastidas@spm.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 73 / 228 enviado
# ============================================================
# {'Nombre': 'Carlos Rabanal', 'Correo': 'Crabanal17@gmail.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 74 / 228 enviado
# ============================================================
# {'Nombre': 'Christian Chalco', 'Correo': 'christian.chalco@hudbayminerals.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 75 / 228 enviado
# ============================================================
# {'Nombre': 'Martín Valqui trujillo', 'Correo': 'mvalqui@mibsac.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 76 / 228 enviado
# ============================================================
# {'Nombre': 'Aldo Adama Navarro', 'Correo': 'aadama@antamina.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 77 / 228 enviado
# ============================================================
# {'Nombre': 'Maximo Simon Z. ', 'Correo': 'msimon@poderosa.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 78 / 228 enviado
# ============================================================
# {'Nombre': 'Mario M Echeverria Carrillo', 'Correo': 'mecheverria@poderosa.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 79 / 228 enviado
# ============================================================
# {'Nombre': 'Miguel Ocampo Cornejo', 'Correo': 'mocampoc@fmi.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 80 / 228 enviado
# ============================================================
# {'Nombre': 'Edwin Arica', 'Correo': 'edwin.arica@mmg.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 81 / 228 enviado
# ============================================================
# {'Nombre': 'Luis Herrera García', 'Correo': 'lherrerag@southernperu.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 82 / 228 enviado
# ============================================================
# {'Nombre': 'Abel Amado Arias', 'Correo': 'aamadoa@southernperu.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 83 / 228 enviado
# ============================================================
# {'Nombre': 'Christian Concha Melo', 'Correo': 'cconcha@southernperu.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 84 / 228 enviado
# ============================================================
# {'Nombre': 'Henry Palomino', 'Correo': 'Henry.Palomino@minsur.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 85 / 228 enviado
# ============================================================
# {'Nombre': 'Julio Palomino', 'Correo': 'julio.palomino@mmg.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 86 / 228 enviado
# ============================================================
# {'Nombre': 'Juan Laos', 'Correo': 'jlaos@antamina.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 87 / 228 enviado
# ============================================================
# {'Nombre': 'Guido Medina', 'Correo': 'guido.medina@zafranal.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 88 / 228 enviado
# ============================================================
# {'Nombre': 'Richard HURTADO ORE\n', 'Correo': 'Richard.hurtado@hocplc.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 89 / 228 enviado
# ============================================================
# {'Nombre': 'Héctor Alfonzo Hernández Mejias', 'Correo': 'hhernanm@aasa.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 90 / 228 enviado
# ============================================================
# {'Nombre': 'Hugo Alburqueque Cabrera', 'Correo': 'hugo.alburqueque@mmg.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 91 / 228 enviado
# ============================================================
# {'Nombre': 'MANUEL RUIZ', 'Correo': 'Manuelruiz@byjsasociados.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 92 / 228 enviado
# ============================================================
# {'Nombre': 'Ricardo Manuel Palma Villanueva', 'Correo': 'Ricardo.Palma@mmg.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 93 / 228 enviado
# ============================================================
# {'Nombre': 'Alan Alexander Aguilar Arista', 'Correo': 'Alan.Aguilar@glencore.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 94 / 228 enviado
# ============================================================
# {'Nombre': 'Segundo Miguel Coronel Campos', 'Correo': 'scoronel@fmi.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 95 / 228 enviado
# ============================================================
# {'Nombre': 'Ronald Lizandro Gomez Fuentes', 'Correo': 'rg.gomez@angloamerican.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 96 / 228 enviado
# ============================================================
# {'Nombre': 'Guido Simeon Pozo Nieto', 'Correo': 'gpozo@chinalco.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 97 / 228 enviado
# ============================================================
# {'Nombre': 'Ryan Fidler', 'Correo': 'rfidler@fmi.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 98 / 228 enviado
# ============================================================
# {'Nombre': 'Paolo Hurtado Gonzales', 'Correo': 'paolohurtado92@gmail.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 99 / 228 enviado
# ============================================================
# {'Nombre': 'Aparicio Rivero', 'Correo': 'arivero@acerosarequipa.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 100 / 228 enviado
# ============================================================
# {'Nombre': 'Javier Hugo Neyra Torres', 'Correo': 'jneyrato@fmi.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 101 / 228 enviado
# ============================================================
# {'Nombre': 'Erick Miguel Portugal Hidalgo', 'Correo': 'erick.portugal@angloamerican.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 102 / 228 enviado
# ============================================================
# {'Nombre': 'Hans Osorio', 'Correo': 'hans.osorio@mmg.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 103 / 228 enviado
# ============================================================
# {'Nombre': 'David Manuel Lopez Escobedo', 'Correo': 'dlopezes@fmi.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 104 / 228 enviado
# ============================================================
# {'Nombre': 'Mijail Hector Quiroz Cárdenas', 'Correo': 'mquiroz@lajoyamining.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 105 / 228 enviado
# ============================================================
# {'Nombre': 'Fredy Ulloa', 'Correo': 'fulloasolis2018@gmail.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 106 / 228 enviado
# ============================================================
# {'Nombre': 'Sergio Leandro Toribio Alva', 'Correo': 'sergio.toribio@buenaventura.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 107 / 228 enviado
# ============================================================
# {'Nombre': 'Jose Hancco Mamani', 'Correo': 'jose.hancco@hudbayminerals.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 108 / 228 enviado
# ============================================================
# {'Nombre': 'Carlos Gutierrez', 'Correo': 'carlos.gutierrez@miskimayo.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 109 / 228 enviado
# ============================================================
# {'Nombre': 'Kenny', 'Correo': 'planeamientomap@shp.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 110 / 228 enviado
# ============================================================
# {'Nombre': 'Claudio Huauya', 'Correo': 'Claudio.Huauya@gmail.com ', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 111 / 228 enviado
# ============================================================
# {'Nombre': 'Adalberto Ortega', 'Correo': 'adalbertoortega@gmail.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Venezuela'}
# Correo 112 / 228 enviado
# ============================================================
# {'Nombre': 'David Alfredo Fernandez Rojas', 'Correo': 'dfernand3@fmi.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 113 / 228 enviado
# ============================================================
# {'Nombre': 'Henry Bueno', 'Correo': 'hbueno@antamina.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 114 / 228 enviado
# ============================================================
# {'Nombre': 'Marcial Medina', 'Correo': 'marcial.medina@hudbayminerals.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 115 / 228 enviado
# ============================================================
# {'Nombre': 'Gustavo Calero', 'Correo': 'gustavo.calero@miskimayo.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 116 / 228 enviado
# ============================================================
# {'Nombre': 'Elard Choque', 'Correo': 'echoquev@fmi.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 117 / 228 enviado
# ============================================================
# {'Nombre': 'Edwin Valenzuela Zela', 'Correo': 'evalenzuelaz@southernperu.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 118 / 228 enviado
# ============================================================
# {'Nombre': 'William', 'Correo': 'planeamientomap@shp.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 119 / 228 enviado
# ============================================================
# {'Nombre': 'Percy Perez', 'Correo': 'pperez@chinalco.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 120 / 228 enviado
# ============================================================
# {'Nombre': 'Manuel Rosas', 'Correo': 'mrosas@shp.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 121 / 228 enviado
# ============================================================
# {'Nombre': 'Smith Torres', 'Correo': 'smith.torres@seprocal.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 122 / 228 enviado
# ============================================================
# {'Nombre': 'Juan José Cahuana Cuba', 'Correo': 'jcahuana@fmi.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 123 / 228 enviado
# ============================================================
# {'Nombre': 'Manolo Lozano', 'Correo': 'mlozano@colquisiri.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 124 / 228 enviado
# ============================================================
# {'Nombre': 'Silvia Armas Rivas', 'Correo': 'sarmas@chinalco.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 125 / 228 enviado
# ============================================================
# {'Nombre': 'Elmer Ruiz', 'Correo': 'elmer.ruiz@miskimayo.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 126 / 228 enviado
# ============================================================
# {'Nombre': 'Miguel Varas Rios', 'Correo': 'mvarasr@poderosa.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 127 / 228 enviado
# ============================================================
# {'Nombre': 'Rubén Pineda', 'Correo': 'rpineda@shp.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 128 / 228 enviado
# ============================================================
# {'Nombre': 'José Luperdi', 'Correo': 'JOSE.LUPERDI@mosaicco.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 129 / 228 enviado
# ============================================================
# {'Nombre': 'Milton Mamani', 'Correo': 'milton.mamani@samancomining.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 130 / 228 enviado
# ============================================================
# {'Nombre': 'Ismael Ramírez González', 'Correo': 'iramirezg@southernperu.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 131 / 228 enviado
# ============================================================
# {'Nombre': 'Carlos Castro', 'Correo': 'carlos.castro@mmg.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 132 / 228 enviado
# ============================================================
# {'Nombre': 'Armando Farfán Arias', 'Correo': 'jefe.mantenimiento@ferrosalt.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 133 / 228 enviado
# ============================================================
# {'Nombre': 'Raúl Machuca', 'Correo': 'planeamientomap@shp.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 134 / 228 enviado
# ============================================================
# {'Nombre': 'Daniel Castañeda', 'Correo': 'Daniel.Castaneda@miskimayo.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 135 / 228 enviado
# ============================================================
# {'Nombre': 'Arquimides Aguilar', 'Correo': 'aaguilarc@southernperu.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 136 / 228 enviado
# ============================================================
# {'Nombre': 'Hernando Valdivia L.', 'Correo': 'hvaldivia@antamina.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 137 / 228 enviado
# ============================================================
# {'Nombre': 'Jaime Lira', 'Correo': 'jlira@southernperu.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 138 / 228 enviado
# ============================================================
# {'Nombre': 'Richard Becerra', 'Correo': 'richard.becerra2@newmont.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 139 / 228 enviado
# ============================================================
# {'Nombre': 'HELDER MEJIA', 'Correo': 'hmejia@comsigua.com.ve', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Venezuela'}
# Correo 140 / 228 enviado
# ============================================================
# {'Nombre': 'Oscar Rodriguez Hoyos', 'Correo': 'orodriguezh@southernperu.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 141 / 228 enviado
# ============================================================
# {'Nombre': 'Danny Andía Díaz', 'Correo': 'danny.andia@mmg.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 142 / 228 enviado
# ============================================================
# {'Nombre': 'Julio Canorio', 'Correo': 'JULIO.CANORIO@miskimayo.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 143 / 228 enviado
# ============================================================
# {'Nombre': 'LUIS ALBERTO CHAMBI VALDIVIA', 'Correo': 'lchambiv@fmi.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 144 / 228 enviado
# ============================================================
# {'Nombre': 'José Pérez Alvarez', 'Correo': 'jpereza@southernperu.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 145 / 228 enviado
# ============================================================
# {'Nombre': 'Manuel Puemape Marconl', 'Correo': 'mpuemape@shp.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 146 / 228 enviado
# ============================================================
# {'Nombre': 'Juan Carlos Felipa Chambi', 'Correo': 'jfelipac@fmi.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 147 / 228 enviado
# ============================================================
# {'Nombre': 'Jhon Huayhua Becerra', 'Correo': 'jhuayhua@shp.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 148 / 228 enviado
# ============================================================
# {'Nombre': 'Heudin Valerio', 'Correo': 'dpto.tecnico.pellas@gmail.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Venezuela'}
# Correo 149 / 228 enviado
# ============================================================
# {'Nombre': 'Zusally Vásquez', 'Correo': 'zvasquez@venprecar.com.ve', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Venezuela'}
# Correo 150 / 228 enviado
# ============================================================
# {'Nombre': 'Vladimir Asto', 'Correo': ' Vladimir.Asto@minsur.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 151 / 228 enviado
# ============================================================
# {'Nombre': 'Maykel Bustamante', 'Correo': 'maykel.bustamante@elbrocal.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 152 / 228 enviado
# ============================================================
# {'Nombre': 'Roberto Aguirre', 'Correo': 'raguirre@shp.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 153 / 228 enviado
# ============================================================
# {'Nombre': 'Fernando Alburqueque', 'Correo': 'falburqueque@chinalco.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 154 / 228 enviado
# ============================================================
# {'Nombre': 'Raul Andrade', 'Correo': 'randradeq@chinalco.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 155 / 228 enviado
# ============================================================
# {'Nombre': 'Francisco Rozas', 'Correo': 'francisco.rozas@zafranal.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 156 / 228 enviado
# ============================================================
# {'Nombre': 'Ricardo Alfredo Vásquez García', 'Correo': 'rvasquezg@southernperu.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 157 / 228 enviado
# ============================================================
# {'Nombre': 'LUIS RONDON', 'Correo': 'lrondon@comsigua.com.ve', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Venezuela'}
# Correo 158 / 228 enviado
# ============================================================
# {'Nombre': 'Fernando Salazar Tejada', 'Correo': 'fsalazar1@fmi.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 159 / 228 enviado
# ============================================================
# {'Nombre': 'Marco Antonio Figueroa Quijada', 'Correo': 'mfigueroaq@southernperu.com.pe', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 160 / 228 enviado
# ============================================================
# {'Nombre': 'Eder Perez', 'Correo': 'eperezsa@fmi.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 161 / 228 enviado
# ============================================================
# {'Nombre': 'Carolina Rodriguez', 'Correo': 'rcarolina@venprecar.com.ve', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Venezuela'}
# Correo 162 / 228 enviado
# ============================================================
# {'Nombre': 'Juan Añorga', 'Correo': 'janorga@venprecar.com.ve', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Venezuela'}
# Correo 163 / 228 enviado
# ============================================================
# {'Nombre': 'Aldo Cantafio', 'Correo': 'aldocantafio0@gmail.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Venezuela'}
# Correo 164 / 228 enviado
# ============================================================
# {'Nombre': 'Miguel Porras', 'Correo': 'mporras@antamina.com', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 165 / 228 enviado
# ============================================================
# {'Nombre': 'Jorge Luis Galarza Herrera', 'Correo': 'jorge.galarza@glencore.com.pe ', 'Area': 'Planta', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 166 / 228 enviado
# ============================================================
# {'Nombre': 'Brandon Merma', 'Correo': 'brandon.merma@hudbayminerals.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 167 / 228 enviado
# ============================================================
# {'Nombre': 'Alexandra Cusi', 'Correo': 'alexandra.cusi@hudbayminerals.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 168 / 228 enviado
# ============================================================
# {'Nombre': 'Omar Marrón', 'Correo': 'omar.marron@hudbayminerals.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 169 / 228 enviado
# ============================================================
# {'Nombre': 'Alexis Cruz Reyes', 'Correo': 'carlos.cruz@hudbayminerals.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 170 / 228 enviado
# ============================================================
# {'Nombre': 'Jorge Díaz', 'Correo': 'jorge.diaz@angloamerican.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 171 / 228 enviado
# ============================================================
# {'Nombre': 'Elizabeth Romero', 'Correo': 'elizabeth.romero@nexaresources.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 172 / 228 enviado
# ============================================================
# {'Nombre': 'Jhosmely Espinoza', 'Correo': 'jhosmely.espinoza@nexaresources.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 173 / 228 enviado
# ============================================================
# {'Nombre': 'Lessly Cervera ', 'Correo': 'lessly.cervera@hudbayminerals.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 174 / 228 enviado
# ============================================================
# {'Nombre': 'Walter Luis Tapia Pérez', 'Correo': 'Walter.tapia@xylem.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 175 / 228 enviado
# ============================================================
# {'Nombre': 'Llerena Quiroz, Margaret Brisaida', 'Correo': 'margaret.llerena@angloamerican.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 176 / 228 enviado
# ============================================================
# {'Nombre': 'Daniela Lovón', 'Correo': 'daniela.lovon@marcobre.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 177 / 228 enviado
# ============================================================
# {'Nombre': 'Fabiola Guillén', 'Correo': 'fguillen@cosapi.com.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': ''}
# Correo 178 / 228 enviado
# ============================================================
# {'Nombre': 'Angie Alcca', 'Correo': 'aalcca@cosapi.com.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 179 / 228 enviado
# ============================================================
# {'Nombre': 'Procura San Gabriel', 'Correo': 'procurasangabriel@buenaventura.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': ''}
# Correo 180 / 228 enviado
# ============================================================
# {'Nombre': 'Andre Aguilar', 'Correo': 'andre.aguilar@buenaventura.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 181 / 228 enviado
# ============================================================
# {'Nombre': 'Daniel Yanac', 'Correo': 'kolpa-logistica@kolpa.com.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 182 / 228 enviado
# ============================================================
# {'Nombre': 'Logística Caravelí', 'Correo': 'logistica_cmc@cmc.com.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 183 / 228 enviado
# ============================================================
# {'Nombre': 'Luis Laurente', 'Correo': 'llaurente@poderosa.com.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 184 / 228 enviado
# ============================================================
# {'Nombre': 'Carlos García Monterroso', 'Correo': 'cgarciam@poderosa.com.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 185 / 228 enviado
# ============================================================
# {'Nombre': 'Gerardo Alonso', 'Correo': 'Gerardo.alonso@spm.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 186 / 228 enviado
# ============================================================
# {'Nombre': 'Manuel Grieve Marín', 'Correo': 'dyanac@kolpa.com.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 187 / 228 enviado
# ============================================================
# {'Nombre': 'Marilyn Arias Surco', 'Correo': 'marias@sierrasungroup.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 188 / 228 enviado
# ============================================================
# {'Nombre': 'Rodrigo Haro', 'Correo': 'rodrigo.haro@marcobre.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 189 / 228 enviado
# ============================================================
# {'Nombre': 'Luz Sakihara', 'Correo': 'luz.sakihara@nexaresources.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 190 / 228 enviado
# ============================================================
# {'Nombre': 'Kerly Rodriguez', 'Correo': 'kerly.rodriguez@nexaresources.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 191 / 228 enviado
# ============================================================
# {'Nombre': 'Luis Jimenez', 'Correo': 'luis.jimenez@marcobre.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 192 / 228 enviado
# ============================================================
# {'Nombre': 'Victor Lavado', 'Correo': 'victor.lavado@spm.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 193 / 228 enviado
# ============================================================
# {'Nombre': 'Jessica Atoche Rojas', 'Correo': 'jatoche@remicsa.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 194 / 228 enviado
# ============================================================
# {'Nombre': 'Carlos Macavilca', 'Correo': 'cmacavilca@sierrasungroup.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 195 / 228 enviado
# ============================================================
# {'Nombre': 'Alvaro Camacho', 'Correo': 'Alvaro.Camacho@spm.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 196 / 228 enviado
# ============================================================
# {'Nombre': 'Luis Garro', 'Correo': 'luis.garro@spm.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 197 / 228 enviado
# ============================================================
# {'Nombre': 'Judith Bravo', 'Correo': 'judith.bravo@buenaventura.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 198 / 228 enviado
# ============================================================
# {'Nombre': 'Ximena Alarcón', 'Correo': 'ximena.alarcon@buenaventura.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 199 / 228 enviado
# ============================================================
# {'Nombre': 'Renato Rodríguez Leon', 'Correo': 'compras@acerosarequipa.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 200 / 228 enviado
# ============================================================
# {'Nombre': 'Wili Chirinos', 'Correo': 'wili.chirinos@yura.com.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 201 / 228 enviado
# ============================================================
# {'Nombre': 'Victor Alejandro Vargas Velasquez', 'Correo': 'victor.vargas@sider.com.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 202 / 228 enviado
# ============================================================
# {'Nombre': 'Alfredo Octavio Agurto Grados', 'Correo': 'alfredo.agurto@laytaruma.com.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 203 / 228 enviado
# ============================================================
# {'Nombre': 'Ricardo Raúl Andujar', 'Correo': 'ricardo.andujar@minsur.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 204 / 228 enviado
# ============================================================
# {'Nombre': 'Martín Chavez López', 'Correo': 'martin.chavez@buenaventura.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 205 / 228 enviado
# ============================================================
# {'Nombre': 'Aldo Rendón', 'Correo': 'arendon@aasa.com.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 206 / 228 enviado
# ============================================================
# {'Nombre': 'Rafael Guillén', 'Correo': 'rafael.guillen@buenaventura.pe ', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 207 / 228 enviado
# ============================================================
# {'Nombre': 'Carlo Roncero', 'Correo': 'cronceros@mtp.com.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 208 / 228 enviado
# ============================================================
# {'Nombre': 'Anibal La Puente', 'Correo': 'alapuente@poderosa.com.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 209 / 228 enviado
# ============================================================
# {'Nombre': 'Carla Salinas', 'Correo': 'carla.salinas@cementosur.com.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 210 / 228 enviado
# ============================================================
# {'Nombre': 'Rossmary Betetta', 'Correo': 'rbetetta@shp.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 211 / 228 enviado
# ============================================================
# {'Nombre': 'Franklin Gonzalez', 'Correo': 'fgelklin@venprecar.com.ve', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Venezuela'}
# Correo 212 / 228 enviado
# ============================================================
# {'Nombre': 'Jorge Luis Martinez', 'Correo': 'jlmartinez@antamina.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 213 / 228 enviado
# ============================================================
# {'Nombre': 'Erika Blass', 'Correo': 'eBLAS@ADGEMINCO.PE', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 214 / 228 enviado
# ============================================================
# {'Nombre': 'Jorge Coral', 'Correo': 'jorge.coral@mmg.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 215 / 228 enviado
# ============================================================
# {'Nombre': 'Joel Morales Santiago', 'Correo': 'jMORALES@ADGEMINCO.PE', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 216 / 228 enviado
# ============================================================
# {'Nombre': 'Ever Yampasi', 'Correo': 'eyampasi@shp.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 217 / 228 enviado
# ============================================================
# {'Nombre': 'Aaron E Sovero Boza', 'Correo': 'asovero@ferrosalt.com.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 218 / 228 enviado
# ============================================================
# {'Nombre': 'María Fernanda Domínguez', 'Correo': 'maferdominguezz@hotmail.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Venezuela'}
# Correo 219 / 228 enviado
# ============================================================
# {'Nombre': 'Ramón Serra Fuertes', 'Correo': 'rserra@cmc.com.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 220 / 228 enviado
# ============================================================
# {'Nombre': 'Carlos L. Cabrera Quispe', 'Correo': 'LAM1@GRUMART.PE', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 221 / 228 enviado
# ============================================================
# {'Nombre': 'Liset Romero', 'Correo': 'liset.romero@mmg.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 222 / 228 enviado
# ============================================================
# {'Nombre': 'Ruth Camavilca', 'Correo': 'rcamavilca@poderosa.com.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 223 / 228 enviado
# ============================================================
# {'Nombre': 'Andrea Villanueva', 'Correo': 'avillanueva@cmc.com.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 224 / 228 enviado
# ============================================================
# {'Nombre': 'Michele Villegas', 'Correo': 'mvillegas@antamina.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 225 / 228 enviado
# ============================================================
# {'Nombre': 'Priscila Peña Acosta', 'Correo': 'ppena@aasa.com.pe', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 226 / 228 enviado
# ============================================================
# {'Nombre': 'Franking Córdova', 'Correo': 'fcordova@higher-tech.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 227 / 228 enviado
# ============================================================
# {'Nombre': 'Marco Villalta', 'Correo': 'marco.villalta@mmg.com', 'Area': 'Compras', 'NO Correo Masivo': False, 'País': 'Perú'}
# Correo 228 / 228 enviado
# ============================================================
# FIN
